# %% [markdown]
# # Programa Ingenias+ Data Science

# %% [markdown]
# Un proyecto de data science tiene varias etapas:
#
# 1. Recolección de Datos
# 2. Exploración y Procesamiento de los datos
# 3. Modelado
# 4. Puesta en Producción
#
# Si bien la recoleccion de los datos es uno de los pasos más importante de cualquier proyecto, el Data Scientist puede tener desde mucho hasta nada de control en esta etapa. Muy frecuentemente, los data scientist tienen que trabajar con datos guardados en archivos excel, o csv que proveen los clientes.
#
# De cualquier manera, poder leer estos datos, organizarlos, darles el formato correcto, inspeccionarlos y manipularlos es una tarea escencial y requiere librerias especiales, que veremos a lo largo de esta Notebook.

# %% [markdown]
# ## 1. RECOLECCIÓN DE DATOS
# Este primer paso es fundamental y establece la base para todo el proyecto. La **calidad** y la **cantidad** de los datos recopilados pueden influir significativamente en los resultados finales.
# Sin embargo, el control que tiene el Data Scientist sobre esta etapa puede variar considerablemente. En muchos casos, los datos son proporcionados por los clientes en formatos como archivos Excel o CSV.
# Aunque la disponibilidad y la calidad de estos datos pueden ser variables, es responsabilidad del Data Scientist garantizar que se puedan utilizar de manera efectiva para el análisis
#
# **EJEMPLO:** en un proyecto de análisis de marketing para una empresa minorista, los datos pueden incluir transacciones de ventas, datos demográficos de los clientes y registros de interacciones en redes sociales. La recolección y la integración de estos diversos conjuntos de datos son fundamentales para obtener una comprensión completa del comportamiento del cliente y las tendencias del mercado.

# %% [markdown]
# <font size=5>  👩🏽‍🔬 2. Exploración de los datos 👩🏽‍💻</font>

# %% [markdown]
# Una de las primeras cosas que debe realizar un Data Scientist al iniciar un nuevo proyecto es conocer el dataset con el cual va a trabajar. Este paso se conoce como <font color='#1ABC9C'>_"Analisis exploratorio de datos"_</font>.
#
# Este análisis, que es parte de nuestra etapa de exploración y procesamiento de los datos, es muy importante ya que nos permitira descubrir patrones presentes en los datos. También permitira ver aquellos datos que se alejen del comportamiento esperado.
#
# Cuando uno inicia un proyecto de Data Science el primer impulso es saltar a ajustar un modelo de machine learning. Sin embargo, es muy probable que no podamos explicar sus resultados, o no podamos entender que debemos ajustar si no hemos realizado previamente un analisis exploratorio.
#
# Por este motivo, nos abocaremos a explorar nuestros datos en esta Notebook.

# %% [markdown]
# Una vez que se **recopilan los datos**, la siguiente etapa implica explorar y procesarlos para comprender su estructura y características. Esto puede incluir la identificación de **valores atípicos**, la imputación de **datos faltantes** y la **normalización de variables**. Además, esta etapa a menudo implica la **visualización** de los datos para identificar **patrones o tendencias** que puedan guiar el análisis posterior.
#
# **EJEMPLO:** en un proyecto de análisis de datos de salud, esta etapa podría involucrar la exploración de datos médicos para identificar relaciones entre diferentes variables, como la edad, el género y los factores de riesgo de enfermedades crónicas.

# %% [markdown]
# ## 3.  MODELADO
#
# Una vez que los datos se han explorado y procesado, se pueden desarrollar modelos predictivos o descriptivos para extraer información significativa. Esto puede implicar el uso de técnicas estadísticas, aprendizaje automático o minería de datos para generar hipótesis, hacer predicciones o identificar patrones ocultos en los datos.
#
# **EJEMPLO:** en un proyecto de análisis de sentimientos en redes sociales, se podrían aplicar algoritmos de aprendizaje automático para clasificar automáticamente los mensajes como positivos, negativos o neutrales, lo que permite a las empresas comprender mejor la percepción del público sobre sus productos o servicios.
#
#
#
# ## 4. PUESTA EN PRODUCCIÓN
# Finalmente, los modelos desarrollados en la etapa de modelado se implementan en un entorno de producción para su uso en la toma de decisiones en tiempo real o para la automatización de procesos comerciales. Esta etapa puede requerir la **integración** de los modelos en sistemas existentes, así como la **monitorización** continua para garantizar su rendimiento y precisión a lo largo del tiempo.
#
# **EJEMPLO:** en un proyecto de análisis de fraudes financieros, los modelos desarrollados para detectar transacciones sospechosas pueden integrarse en el sistema de detección de fraudes de una institución financiera, donde se ejecutan en tiempo real para identificar y prevenir actividades fraudulentas.

# %% [markdown]
# ## Primera Parte: Describiendo los datos

# %% [markdown]
# Imaginemos la siguiente situación: Trabajas como data scientist en una empresa que comercializa distintos productos. La empresa tiene datos de ventas del Black Friday del año pasado. Tu Team leader te provee el dataset en el archivo `blackfriday.csv` y te pide que pienses en que proyecto puede surgir de allí que tenga utilidad para la empresa.

# %%
#importa pandas
import pandas as pd
import numpy as np

# %% [markdown]
# Recordemos que la sintaxis para poder leer un archivo csv es:
#
# `df = pd.read_csv('archivo.csv', delimiter=',')`
#
# Aunque muchas veces se omite el `delimiter` si el archivo esta separado por comas.

# %% [markdown]
# Lee el archivo csv `bkackfriday.csv` usando `pandas`. Guardalo en una variable llamada `blackfriday`.

# %%
#blackfriday = pd.read_csv('blackfriday.csv')

#from google.colab import files
#uploaded = files.upload()

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
ruta_del_archivo = '/content/drive/My Drive/JUMP/Propuestas/Clase 9 - Exploración de datos/blackfriday.csv'

df = pd.read_csv(ruta_del_archivo) # Importar el archivo CSV

# %% [markdown]
# Visualiza el DataFrame y observa cuantas filas y columnas tiene.

# %%
blackfriday = df

# %%
blackfriday.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  14.0        10.0             A
# 1  1000001  P00248942      F  15.0         NaN             A
# 2  1000001  P00087842    NaN  15.0        10.0             A
# 3  1000001  P00085442      F  15.0        10.0             A
# 4  1000002  P00285442      M  60.0        16.0             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN    8370.0
# 1                 6.0                14.0   15200.0
# ...

# %%
blackfriday.shape
# Out:
# (537577, 12)

# %% [markdown]
# Nombre y tipo de datos en las columnas contenidas en `blackfriday`

# %%
blackfriday.columns
# Out:
# Index(['User_ID', 'Product_ID', 'Gender', 'Age', 'Occupation', 'City_Category',
#        'Stay_In_Current_City_Years', 'Marital_Status', 'Product_Category_1',
#        'Product_Category_2', 'Product_Category_3', 'Purchase'],
#       dtype='object')

# %%
blackfriday.dtypes
# Out:
# User_ID                         int64
# Product_ID                     object
# Gender                         object
# Age                           float64
# Occupation                    float64
# City_Category                  object
# Stay_In_Current_City_Years     object
# Marital_Status                  int64
# Product_Category_1              int64
# Product_Category_2            float64
# Product_Category_3            float64
# Purchase                      float64
# dtype: object

# %%
blackfriday.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 537577 entries, 0 to 537576
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   User_ID                     537577 non-null  int64
#  1   Product_ID                  537577 non-null  object
#  2   Gender                      483819 non-null  object
#  3   Age                         510698 non-null  float64
#  4   Occupation                  456940 non-null  float64
#  5   City_Category               537577 non-null  object
#  6   Stay_In_Current_City_Years  537577 non-null  object
#  7   Marital_Status              537577 non-null  int64
#  8   Product_Category_1          537577 non-null  int64
#  9   Product_Category_2          370591 non-null  float64
#  10  Product_Category_3          164278 non-null  float64
#  11  Purchase                    526825 non-null  float64
# dtypes: float64(5), int64(3), object(4)
# ...

# %% [markdown]
# Chequea si tiene valores faltantes y ver las filas que los tienen.

# %%
blackfriday.isna() #no veo el resumen, sino booleanos por cada información
# Out:
#         User_ID  Product_ID  Gender    Age  Occupation  City_Category  \
# 0         False       False   False  False       False          False
# 1         False       False   False  False        True          False
# 2         False       False    True  False       False          False
# 3         False       False   False  False       False          False
# 4         False       False   False  False       False          False
# ...         ...         ...     ...    ...         ...            ...
# 537572    False       False   False  False       False          False
# 537573    False       False   False  False       False          False
# 537574    False       False   False  False       False          False
# 537575    False       False   False  False       False          False
# 537576    False       False   False  False       False          False
#
#         Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# ...

# %%
blackfriday.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 537577 entries, 0 to 537576
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   User_ID                     537577 non-null  int64
#  1   Product_ID                  537577 non-null  object
#  2   Gender                      483819 non-null  object
#  3   Age                         510698 non-null  float64
#  4   Occupation                  456940 non-null  float64
#  5   City_Category               537577 non-null  object
#  6   Stay_In_Current_City_Years  537577 non-null  object
#  7   Marital_Status              537577 non-null  int64
#  8   Product_Category_1          537577 non-null  int64
#  9   Product_Category_2          370591 non-null  float64
#  10  Product_Category_3          164278 non-null  float64
#  11  Purchase                    526825 non-null  float64
# dtypes: float64(5), int64(3), object(4)
# ...

# %%
blackfriday.isna().sum() # la suma por cada columna
# Out:
# User_ID                            0
# Product_ID                         0
# Gender                         53758
# Age                            26879
# Occupation                     80637
# City_Category                      0
# Stay_In_Current_City_Years         0
# Marital_Status                     0
# Product_Category_1                 0
# Product_Category_2            166986
# Product_Category_3            373299
# Purchase                       10752
# dtype: int64

# %%
blackfriday[blackfriday.isna().any(axis=1)] # al menos uno en alguna columna
# Out:
#         User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0       1000001  P00069042      F  14.0        10.0             A
# 1       1000001  P00248942      F  15.0         NaN             A
# 2       1000001  P00087842    NaN  15.0        10.0             A
# 3       1000001  P00085442      F  15.0        10.0             A
# 4       1000002  P00285442      M  60.0        16.0             C
# ...         ...        ...    ...   ...         ...           ...
# 537570  1004736  P00162442      M  22.0         NaN             A
# 537572  1004737  P00193542      M  43.0        16.0             C
# 537574  1004737  P00345942      M  41.0        16.0             C
# 537575  1004737  P00285842      M  38.0        16.0             C
# 537576  1004737  P00118242      M  43.0        16.0             C
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               0                   3
# ...

# %%
blackfriday.columns
# Out:
# Index(['User_ID', 'Product_ID', 'Gender', 'Age', 'Occupation', 'City_Category',
#        'Stay_In_Current_City_Years', 'Marital_Status', 'Product_Category_1',
#        'Product_Category_2', 'Product_Category_3', 'Purchase'],
#       dtype='object')

# %%
blackfriday[blackfriday['Gender'].isna()] # seleccion de columna de interés
# Out:
#         User_ID Product_ID Gender   Age  Occupation City_Category  \
# 2       1000001  P00087842    NaN  15.0        10.0             A
# 24      1000008  P00303442    NaN  26.0        12.0             C
# 38      1000010  P00155442    NaN  39.0         NaN             B
# 40      1000010  P00087242    NaN  40.0         1.0             B
# 42      1000010  P00259342    NaN  41.0         1.0             B
# ...         ...        ...    ...   ...         ...           ...
# 537533  1004732  P00209842    NaN  29.0         NaN             B
# 537543  1004732  P00117242    NaN  29.0         NaN             B
# 537549  1004734  P00345842    NaN  53.0         1.0             B
# 537550  1004735  P00278242    NaN  47.0         3.0             C
# 537565  1004736  P00051142    NaN  23.0        20.0             A
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 2                               2               0                  12
# ...

# %%
blackfriday_sin_nulos = blackfriday.dropna() # sin los nulos
blackfriday_sin_nulos
# Out:
#         User_ID Product_ID Gender   Age  Occupation City_Category  \
# 6       1000004  P00184942      M  48.0         7.0             B
# 13      1000005  P00145042      M  33.0        20.0             A
# 14      1000006  P00231342      F  51.0         9.0             A
# 18      1000007  P00036842      M  38.0         1.0             B
# 19      1000008  P00249542      M  27.0        12.0             C
# ...         ...        ...    ...   ...         ...           ...
# 537547  1004733  P00244042      M  18.0        18.0             C
# 537551  1004735  P00313442      M  49.0         3.0             C
# 537562  1004736  P00146742      M  23.0        20.0             A
# 537571  1004737  P00221442      M  43.0        16.0             C
# 537573  1004737  P00111142      M  37.0        16.0             C
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 6                               2               1                   1
# ...

# %% [markdown]
# Detalles estadisticos de cada columna:

# %%
blackfriday.describe()
# Out:
#             User_ID            Age     Occupation  Marital_Status  \
# count  5.375770e+05  510698.000000  456940.000000   537577.000000
# mean   1.002992e+06      34.321239       8.083580        0.408797
# std    1.714393e+03      11.640546       6.523685        0.491612
# min    1.000001e+06      14.000000       0.000000        0.000000
# 25%    1.001495e+06      26.000000       2.000000        0.000000
# 50%    1.003031e+06      32.000000       7.000000        0.000000
# 75%    1.004417e+06      42.000000      14.000000        1.000000
# max    1.006040e+06      74.000000      20.000000        1.000000
#
#        Product_Category_1  Product_Category_2  Product_Category_3  \
# count       537577.000000       370591.000000       164278.000000
# mean             5.295546            9.842144           12.669840
# std              3.750701            5.087259            4.124341
# min              1.000000            2.000000            3.000000
# ...

# %% [markdown]
# - count: El número de valores **no nulos** en la columna.
# - mean: La media de los valores en la columna.
# - std: La desviación estándar de los valores en la columna.
# - min: El valor mínimo de la columna.
# - 25%, 50%, 75%: Los percentiles 25, 50 (mediana) y 75 de los valores en la columna, respectivamente.
# - max: El valor máximo de la columna.

# %%
# Count: número de valores no nulos
count_age = blackfriday['Age'].count()
count_age
# Out:
# 510698

# %%
# Mean: media
mean_age = blackfriday['Age'].mean().round(3) # y redondear?
mean_age
# Out:
# 34.321

# %%
# Std: desviación estándar
std_age = blackfriday['Age'].std()
std_age
# Out:
# 11.640545751023325

# %%
# Min: valor mínimo
min_age = blackfriday['Age'].max() # y el máximo??
min_age
# Out:
# 74.0

# %%
# 25%, 50% (median), 75%: percentiles
percentiles_age = blackfriday['Age'].quantile([0.25, 0.5, 0.75])
percentiles_age

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Es una medida de posición (ordenados los datos de menor a mayor) e indica, el valor de la variable por debajo del cual se encuentra un porcentaje dado de observaciones en un grupo de datos.
#
# El 25% de mis datos tiene: --- igual o menor
#
# El 50% de los datos (mediana) --- igual o menor
#
# El 75% de los datos -- igual o menor

# %% [markdown]
# ### Moda - Mediana - Media

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Media:** el promedio de un conjunto de números. Para calcularla: sumamos todos los números y  dividimos por la cantidad total de números.
# Ejemplo: 2, 4, 6 y 8, la media sería (2 + 4 + 6 + 8) / 4 = 5.
#
# (La media da una idea de la tendencia central de los datos)
#
#
# **Moda:** es el número que aparece con mayor frecuencia en un conjunto de datos.
# Se podria encontrar contando cuántas veces aparece cada número y seleccionando el que aparece con más frecuencia.
# Ejemplo: 2, 2, 4, 6 y 8, la moda sería 2
#
# (La moda ayuda a identificar los valores más comunes en los datos.)
#
#
# **Mediana:** es el valor que ocupa la posición central en un conjunto de datos ordenados. Para calcularla, primero ordenamos los números de menor a mayor y luego seleccionamos el número en la posición central.
# Si hay un número impar de datos, la mediana es el número en el medio.
# Si hay un número par de datos, la mediana es el promedio de los dos números en el medio. Ejemplo:
#
# 2, 4, 6, 7 y 8, la mediana sería 6
#
# 2, 4, 6 y 8, la mediana sería 5 ((4 + 6) / 2 = 5)
#
# (La mediana ayuda a entender cómo se distribuyen los datos en relación con su valor central.)

# %% [markdown]
# Podemos ver tambien que valores o categorias estan incluidas en las columnas:

# %%
blackfriday.columns  # recordemos las columnas de nuestro df
# Out:
# Index(['User_ID', 'Product_ID', 'Gender', 'Age', 'Occupation', 'City_Category',
#        'Stay_In_Current_City_Years', 'Marital_Status', 'Product_Category_1',
#        'Product_Category_2', 'Product_Category_3', 'Purchase'],
#       dtype='object')

# %%
blackfriday["City_Category"].value_counts()
# Out:
# City_Category
# B    226493
# C    166446
# A    144638
# Name: count, dtype: int64

# %%
blackfriday["City_Category"].value_counts(normalize=True)
# Out:
# City_Category
# B    0.421322
# C    0.309623
# A    0.269055
# Name: proportion, dtype: float64

# %%
0.421322+ 0.309623+0.269055
# Out:
# 1.0

# %% [markdown]
# **Normaliza los resultados para que sumen 1.**
#
# Calcula la frecuencia relativa en lugar de la frecuencia absoluta. Cada valor devuelto representa la proporción de apariciones de esa categoría con respecto al total de observaciones en la columna.

# %%
blackfriday["Marital_Status"].value_counts(normalize=True)

# %%
blackfriday['Stay_In_Current_City_Years'].unique()
# Out:
# array(['2', '4+', '3', '1', '0'], dtype=object)

# %%
blackfriday['Stay_In_Current_City_Years'].value_counts()
# Out:
# Stay_In_Current_City_Years
# 1    189192
# 2     99459
# 3     93312
# 4     82889
# 0     72725
# Name: count, dtype: int64

# %%
blackfriday['Stay_In_Current_City_Years'] = blackfriday['Stay_In_Current_City_Years'].str.replace('4+', '4', regex=False).astype(int)

# %% [markdown]
# Al usar **regex=False**, se trata '4+' como una cadena literal y no como una expresión regular. Después de este reemplazo, todas las instancias de '4+' se convertirán en '4'.
#
# **astype(int)**: Después de realizar el reemplazo anterior, esta parte del código convierte todos los valores en la columna "Stay_In_Current_City_Years" a **enteros**.

# %%
blackfriday.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 537577 entries, 0 to 537576
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   User_ID                     537577 non-null  int64
#  1   Product_ID                  537577 non-null  object
#  2   Gender                      483819 non-null  object
#  3   Age                         510698 non-null  float64
#  4   Occupation                  456940 non-null  float64
#  5   City_Category               537577 non-null  object
#  6   Stay_In_Current_City_Years  537577 non-null  int64
#  7   Marital_Status              537577 non-null  int64
#  8   Product_Category_1          537577 non-null  int64
#  9   Product_Category_2          370591 non-null  float64
#  10  Product_Category_3          164278 non-null  float64
#  11  Purchase                    526825 non-null  float64
# dtypes: float64(5), int64(4), object(3)
# ...

# %%
 # recordemos las columnas de nuestro df

# %%
blackfriday[(blackfriday["City_Category"] == 'A') & (blackfriday["Marital_Status"] == 0)]["Purchase"].max()
# filtros
# Out:
# 23958.0

# %%
blackfriday[(blackfriday["City_Category"] == 'A') & (blackfriday["Marital_Status"] == 0)]["Purchase"].min()

# %%
blackfriday[(blackfriday["Gender"] == 'F') & (blackfriday["Marital_Status"] == 0)]["Purchase"].max()

# %%
# aplicamos agrupamiento - el promedio de lo gastado
blackfriday.groupby(by=[ 'City_Category',  'Gender'])['Purchase'].mean()
# Out:
# City_Category  Gender
# A              F          8636.497553
#                M          9061.146295
# B              F          8592.777069
#                M          9393.940119
# C              F          9259.441144
#                M         10033.803481
# Name: Purchase, dtype: float64

# %%
blackfriday.columns
# Out:
# Index(['User_ID', 'Product_ID', 'Gender', 'Age', 'Occupation', 'City_Category',
#        'Stay_In_Current_City_Years', 'Marital_Status', 'Product_Category_1',
#        'Product_Category_2', 'Product_Category_3', 'Purchase'],
#       dtype='object')

# %%
# tabla de contingencia o tabla cruzada: frecuencia de ocurrencia
pd.crosstab(blackfriday["City_Category"], blackfriday["Gender"])
# que libreria estamos usando?
# Out:
# Gender             F       M
# City_Category
# A              31307   98769
# B              50869  153185
# C              36771  112918

# %%
'''
# ejemplo:
data = {
    'City_Category': ['A', 'A', 'B', 'B', 'B', 'C', 'C', 'C', 'C'],
    'Product_Category_1': ['electro', 'ropa', 'ropa', 'ropa', 'ropa', 'electro', 'electro', 'ropa', 'electro']
}

df = pd.DataFrame(data) # conversión

# tabla de contingencia
tabla_contingencia = pd.crosstab(df['City_Category'], df['Product_Category_1'])
'''

# %% [markdown]
# ## Parte 2: ¿Cómo visualizo mis datos?

# %% [markdown]
# Para poder visualizar los datos y la relación entre las distintas variables, podemos usar dos librerias: `matplotlib` y `seaborn`.

# %% [markdown]
# Documentación:
# - [matplotlib](https://matplotlib.org/3.1.1/contents.html)
# - [seaborn](https://seaborn.pydata.org/)

# %% [markdown]
# https://seaborn.pydata.org/generated/seaborn.scatterplot.html
#
# https://python-graph-gallery.com/

# %% [markdown]
# - Importamos la libreria `matplotlib.pyplot` como `plt`
# - Importamos la libreria seaborn como `sns`

# %%
#Importa las librerias matplotlib y seaborn
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# como practicamos si aun no encuentro un dataset en especial?
penguins = sns.load_dataset('penguins')

#flights = sns.load_dataset('flights')
#titanic = sns.load_dataset('titanic')
#car_crashes = sns.load_dataset('car_crashes')
#fmri = sns.load_dataset('fmri')  # resonancia
#diamonds = sns.load_dataset('diamonds')

# %%
penguins
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %% [markdown]
# Veamos algunos ejemplos de distintos graficos que se pueden obtener con estas librerias.

# %%
blackfriday.dtypes
# Out:
# User_ID                         int64
# Product_ID                     object
# Gender                         object
# Age                           float64
# Occupation                    float64
# City_Category                  object
# Stay_In_Current_City_Years      int64
# Marital_Status                  int64
# Product_Category_1              int64
# Product_Category_2            float64
# Product_Category_3            float64
# Purchase                      float64
# dtype: object

# %% [markdown]
# ## MATPLOTLIB:
#
# matplotlib.pyplot (plt) es una biblioteca en Python muy usada para la visualización de datos.  Genera gráficos a partir de datos contenidos en listas o arrays
#
# Permite crear una variedad de gráficos, desde simples diagramas de dispersión hasta complejas visualizaciones tridimensionales
#
#
# ➜ Proporciona una API (Interfaz de Programación de Aplicaciones): pylab, similar a la de MATLAB.
#
# Matplotlib.pyplot es un módulo de la biblioteca Matplotlib que proporciona una interfaz gráfica de alto nivel para crear visualizaciones en Python. **Combina** las utilidades gráficas del módulo **pyplot** con las capacidades numéricas de **NumPy**, lo que resulta en un entorno de trabajo que se asemeja a MATLAB en términos de manipulación de matrices y vectores, y trazado de gráficas.
#
# Matplotlib.pyplot facilita la **creación de gráficos** mediante una interfaz simple y coherente. Permite a los usuarios crear figuras, subgráficos y trazar líneas, puntos, barras y más, todo ello con una *sintaxis similar* a la de MATLAB. Además, proporciona una amplia gama de funciones para **personalizar** aspectos como colores, estilos, etiquetas y títulos de los gráficos.
#
# Al aprovechar las capacidades de NumPy, Matplotlib.pyplot puede manejar eficientemente datos numéricos en forma de matrices y vectores. Esto permite a los usuarios realizar operaciones matemáticas y estadísticas en sus datos antes de trazarlos, lo que resulta en visualizaciones más informativas y significativas.

# %% [markdown]
# ### Limitaciones Matplotlib
# - Interactividad limitada: Matplotlib está más orientado a la creación de gráficos estáticos que a los gráficos interactivos. Aunque se han desarrollado herramientas adicionales (como mplcursors) para agregar cierta interactividad, la funcionalidad interactiva no está integrada directamente en Matplotlib.
#
# - Estilos predeterminados simples: Aunque Matplotlib ofrece una variedad de estilos predeterminados para los gráficos, estos estilos pueden parecer simples en comparación con algunas de las bibliotecas de visualización más nuevas y modernas. Los gráficos generados por defecto pueden requerir ajustes manuales para lograr una apariencia más atractiva.
#
# - Curva de aprendizaje empinada: Para usuarios nuevos, Matplotlib puede tener una curva de aprendizaje empinada debido a su amplia gama de funcionalidades y a la necesidad de comprender su estructura y sintaxis. La creación de visualizaciones personalizadas y avanzadas puede requerir un conocimiento profundo de la biblioteca.
#
# - Gráficos 3D limitados: Aunque Matplotlib admite gráficos 3D, la funcionalidad para gráficos 3D es más limitada en comparación con otras bibliotecas especializadas en visualización tridimensional, como Mayavi o Plotly.
#
# - Documentación a veces confusa: A pesar de tener una documentación extensa, la estructura y el formato de la documentación de Matplotlib pueden ser confusos para algunos usuarios, lo que puede dificultar la búsqueda de soluciones a problemas específicos.
#
# - Flexibilidad en la personalización: Aunque Matplotlib es altamente personalizable, algunas personalizaciones avanzadas pueden requerir un código adicional y pueden no ser tan intuitivas de implementar como en otras bibliotecas de visualización más modernas. Esto puede dificultar la creación de visualizaciones altamente personalizadas.

# %% [markdown]
# ## SEABORN:
# Seaborn es una biblioteca popular en Python que se utiliza principalmente para crear gráficos estadísticos de una manera simple y efectiva.
#
# - Trazado estadístico: Seaborn se especializa en la creación de gráficos estadísticos, lo que significa que está diseñado para visualizar datos en términos de distribuciones, relaciones y comparaciones entre variables.
#
# - Construido sobre Matplotlib: Seaborn se basa en la biblioteca de visualización de datos Matplotlib. Esto significa que puede aprovechar todas las funcionalidades de Matplotlib y, al mismo tiempo, proporciona una interfaz más amigable y estilizada para la creación de gráficos.
#
# - Estilos y paletas de colores predeterminados: Seaborn proporciona una variedad de estilos y paletas de colores predeterminados que pueden mejorar la apariencia de los gráficos. Estos estilos y paletas están diseñados para hacer que las visualizaciones sean más atractivas y legibles.
#
# - Integración con DataFrames de Pandas: Seaborn está diseñado para funcionar de manera fluida con DataFrames de Pandas, una estructura de datos tabulares popular en Python. Esto hace que sea fácil y conveniente crear gráficos a partir de datos almacenados en DataFrames.

# %% [markdown]
# ### Limitaciones de Seaborn
# - Complejidad limitada: Seaborn está diseñado principalmente para gráficos estadísticos y análisis exploratorio de datos, por lo que puede carecer de la flexibilidad necesaria para crear visualizaciones altamente personalizadas o gráficos complejos.
#
# - Personalización limitada: Aunque Seaborn ofrece una variedad de estilos y paletas de colores predeterminados, la capacidad de personalización de estos estilos puede ser limitada en comparación con bibliotecas más flexibles como Matplotlib. Esto puede dificultar la creación de gráficos con un aspecto específico.
#
# - Documentación limitada: Aunque Seaborn tiene una documentación sólida, puede no ser tan exhaustiva o detallada como la de otras bibliotecas de visualización de datos. Esto puede dificultar la resolución de problemas o la comprensión de características menos utilizadas.
#
# - Gráficos específicos: Seaborn se especializa en ciertos tipos de gráficos estadísticos, como diagramas de dispersión, diagramas de cajas y violines, y matrices de correlación. Si necesitas crear otros tipos de gráficos menos comunes, es posible que Seaborn no sea la mejor opción.
#
# - Requerimientos de recursos: Algunas operaciones en Seaborn, especialmente aquellas que implican un gran número de datos o gráficos complejos, pueden ser intensivas en recursos y pueden llevar más tiempo de procesamiento en comparación con otras bibliotecas más simples.

# %% [markdown]
# ## EJEMPLOS DE GRÁFICOS

# %% [markdown]
# #### Plot:
#
# La función plot() se utiliza en Matplotlib para dibujar puntos (marcadores) en un diagrama. Por defecto, esta función traza una línea que conecta los puntos, creando  un **gráfico de líneas.**
#
# El primer parámetro de la función plot() es una matriz que contiene los puntos del **eje x**, las coordenadas horizontales en el gráfico.
#
# El segundo parámetro de la función plot() es una matriz que contiene los puntos del **eje y**, las coordenadas verticales en el gráfico. Ambos ejes pueden ser una lista de números o un array NumPy que representa la ubicación de los puntos de cada eje.

# %%
# import matplotlib.pyplot as plt

# Datos para los ejes x - y
#x = [1, 2, 3, 4, 5]
#y = [2, 4, 6, 8, 10]
x = np.array ([1,8])
y = np.array ([3,10])

# Crear el gráfico
plt.plot(x, y)

# Etiquetas de los ejes
plt.xlabel('Eje X')
plt.ylabel('Eje Y')

# Título del gráfico - personalizar
plt.title('Gráfico de ejemplo')
#plt.plot(x, y, color='red', linewidth=5)
plt.plot(x, y, color='blue', linewidth=5, linestyle ="-.")

#plt.plot(x, y, color='green', linewidth=5, linestyle =':', label = 'Recta')
#plt.legend()

# Mostrar el gráfico
plt.show()

# %%
# Datos
x = [1, 2, 3, 4, 5]
y = [2, 4, 6, 8, 10]

# Crear figura y ejes
fig, ax = plt.subplots()

# personalizar
ax.plot(x, y, color='pink', linewidth=5, linestyle='--', label='Recta')

# Agregar la leyenda con ubicación en la parte superior y tamaño de fuente 12
ax.legend(loc='upper left', fontsize=12)

# Etiquetas de los ejes
ax.set_xlabel('Eje X')
ax.set_ylabel('Eje Y')

# Título del gráfico con tamaño de fuente 16
ax.set_title('Gráfico con color, grosor y estilo personalizados', fontsize=16)

# Mostrar el gráfico
# Out:
# Text(0.5, 1.0, 'Gráfico con color, grosor y estilo personalizados')

# %% [markdown]
# #### Graficos de linea

# %%
# import matplotlib.pyplot as plt

# EJEMPLO
edades = [18, 25, 30, 35, 40]
compras = [200, 300, 400, 350, 500]

# Gráfico de líneas
plt.plot(edades, compras, marker='o', linestyle='-')
# eje x, eje y, marcador y estilo de linea
# plt.plot(edades, compras, marker='s', linestyle='--', color='red')
# plt.plot(edades, compras, 'go--')

#plt.plot(edades, compras)
#plt.setp(plt.gca().lines, marker='o', linestyle='-')

# Personalizar características del gráfico
plt.xlabel('Edad del Cliente')
plt.ylabel('Monto de Compra')
plt.title('Monto de Compra en función de la Edad')
plt.grid(True)  # Activar la cuadrícula de fondo

# Mostrar el gráfico
plt.show()

# %%
'''
data = {'Edad': [18, 25, 30, 35, 40],
        'Compras': [200, 300, 400, 350, 500]}

df = pd.DataFrame(data)
plt.plot(df['Edad'], df['Compras'], marker='o', linestyle='-')

# Personalizar el gráfico (opcional)
plt.xlabel('Edad')
plt.ylabel('Compras')
plt.title('Compras en función de la Edad')

plt.show()
'''

# %%
'''
pinguinos = sns.load_dataset("penguins")
#Filtrar los datos para un solo tipo de pinguino (por ejemplo, "Adelie")
pinguinos_adelie = pinguinos[pinguinos["species"] == "Adelie"]

# Crear el gráfico de líneas
plt.figure(figsize=(8, 6))  # Establecer el tamaño del gráfico
sns.lineplot(x="flipper_length_mm", y="body_mass_g", data=pinguinos_adelie, marker='o', color='blue')  # Crear el gráfico de líneas
plt.xlabel("Longitud del pico (mm)")  # Etiqueta del eje x
plt.ylabel("Masa corporal (g)")  # Etiqueta del eje y
plt.title("Relación entre la longitud del pico y la masa corporal en pingüinos Adelie")  # Título del gráfico
plt.grid(True)  # Mostrar rejilla
plt.show()  # Mostrar el gráfico
'''

# %% [markdown]
# #### Graficos de dispersión

# %%
# Datos
x = [1, 2, 3, 4, 5]
y = [2, 4, 6, 8, 10]

# Crear el gráfico de dispersión
plt.figure(figsize=(6, 4))  # Establecer el tamaño de la figura
plt.scatter(x, y)  # Crear el gráfico de dispersión
plt.show()  # Mostrar el gráfico

# %%
# Datos
x = [1, 2, 3, 4, 5]
y = [2, 3, 5, 7, 11]

# Crear el gráfico de dispersión
plt.figure(figsize=(6, 4))  # Establecer el tamaño de la figura
plt.scatter(x, y, color='blue', marker='o')  # Crear el gráfico de dispersión
plt.xlabel('Eje X')  # Etiqueta del eje x
plt.ylabel('Eje Y')  # Etiqueta del eje y
plt.title('Gráfico de Dispersión')  # Título del gráfico
plt.grid(True)  # Mostrar rejilla
plt.show()  # Mostrar el gráfico

# %% [markdown]
# #### Graficos de barra
#
# Son una forma común de visualizar datos categóricos

# %%
city_counts = blackfriday['City_Category'].value_counts() #cuantas veces aparece cada categoria
plt.bar(city_counts.index, city_counts.values) # nombre de categorias y las frecuencias
plt.xlabel('Categoría de la Ciudad')
plt.ylabel('Frecuencia')
plt.title('Frecuencia de la Categoría de la Ciudad')
plt.show()

# %% [markdown]
# #### Histogramas:
#
# Matplotlib ofrece una función llamada hist() que permite graficar fácilmente histogramas. Un histograma es una representación visual de la distribución de los datos en forma de barras. Por ejemplo, podemos crear un histograma a partir de una serie de 1000 valores generados a partir de una distribución gaussiana.

# %%
# EJEMPLO
valores = np.random.normal(loc=0, scale=1, size=1000) # 1000 VALORES ALEATORIOS

# Crear el histograma
plt.hist(valores, bins=50, color='blue', alpha=0.7)

# Etiquetas de los ejes y título del gráfico
plt.xlabel('Valor')
plt.ylabel('Frecuencia')
plt.title('Histograma de Valores')

plt.show()

# %%
# EJEMPLO CON NUESTRO DF
plt.hist(blackfriday['Age'], bins=10, color='skyblue', alpha=0.7)
plt.xlabel('Edad')
plt.ylabel('Frecuencia')
plt.title('Distribución de Edad')
plt.show()

# %%
# Grafico Age
plt.figure() # figura  vacia
plt.hist(blackfriday['Purchase'].dropna(), bins=10, color="blue", alpha=0.3)
# contenedores: 10, color, transparencia
plt.ylabel("Cantidad", size=14) # eje y, tamaño de fuente
plt.xlabel("Monto de la compra", size=14) # eje x
plt.title("Distribucion del monto de la compra realizado por los clientes", size=16, pad=25)
# relleno de 25 puntos entre el título y el gráfico
plt.gca().spines["top"].set_visible(False) # oculta el borde superior del gráfico
plt.gca().spines["right"].set_visible(False) # oculta el borde derecho del gráfico
plt.grid(False) # desactiva las líneas de la cuadrícula en el gráfico
plt.show()

# %%
# Grafico Age
plt.figure()
plt.hist(blackfriday['Age'].dropna(), bins=10, color="orange", alpha=0.3)
plt.ylabel("Cantidad", size=14)
plt.xlabel("Edad", size=14)
plt.title("Distribucion de la edad de los clientes", size=16, pad=25)
plt.gca().spines["top"].set_visible(False)
plt.gca().spines["right"].set_visible(False)
plt.grid(False)
plt.show()

# %% [markdown]
# Mi pagina favorita para elegir [colores](https://htmlcolorcodes.com/es/tabla-de-colores/)🎨 &nbsp;🖍

# %% [markdown]
# #### Distplot:
#
# Distribución de datos unidimensional: La distribución de datos se refiere a cómo están distribuidos los valores en un conjunto de datos. Un conjunto de datos unidimensional significa que solo estamos analizando **una variable**.
#
#  *distplot* combina un **histograma** y una **estimación de la función de densidad de kernel** (KDE) para visualizar la distribución de datos. Un histograma muestra la frecuencia de los valores dentro de intervalos de valores (bins), mientras que la KDE es una forma suavizada de representar la distribución de los datos.

# %%
plt.figure()
sns.displot(blackfriday["Purchase"], color="#5ea88e", kde=True) #bins
# kde: estimación de densidad del núcleo, agrega una curva que representa la densidad de probabilidad de los datos
plt.xlabel('Monto de la compra') # eje
plt.ylabel('Frequency') # eje
sns.despine() # elimina las líneas de los bordes superior y derecho - SNS
plt.show()

# %% [markdown]
# #### Boxplot:
#
# o diagrama de caja y bigotes, es una forma simple pero efectiva de representar la distribución de un conjunto de datos numéricos y visualizar las características clave de la distribución
#
# - Caja central: La caja en el centro del gráfico representa el rango intercuartil (IQR), que es la diferencia entre el tercer cuartil (Q3) y el primer cuartil (Q1) del conjunto de datos. El borde inferior de la caja (Q1) indica el valor por debajo del cual se encuentra el 25% de los datos, mientras que el borde superior (Q3) indica el valor por debajo del cual se encuentra el 75% de los datos.
#
# - Línea central: Dentro de la caja, hay una línea que indica la **mediana** del conjunto de datos, que es el valor que separa al 50% de los datos más bajos del 50% de los datos más altos.
#
# - Bigotes (Whiskers): Los bigotes se extienden desde los bordes de la caja hasta los valores extremos del conjunto de datos. La longitud de los bigotes puede variar dependiendo de cómo se defina el rango intercuartil y qué tan lejos se consideran los valores atípicos.
#
# - Puntos atípicos: Los puntos individuales que se encuentran más allá de los bigotes se consideran valores atípicos y se pueden mostrar como puntos individuales en el gráfico.
#
# *Interpretación:* Un boxplot proporciona una manera rápida de identificar la dispersión y la simetría de los datos, así como cualquier valor atípico. También permite comparar fácilmente varias distribuciones de datos en un solo gráfico.

# %%
boxplot_blackfriday = blackfriday.melt(id_vars='City_Category', value_vars=['Purchase'])
# melt: de un formato ancho a un formato largo
# mantenemos city category como id_vars
# cada fila ahora contendrá una combinación de valores de 'City_Category' y 'Purchase'

# %%
boxplot_blackfriday.head()
# Out:
#   City_Category  variable    value
# 0             A  Purchase   8370.0
# 1             A  Purchase  15200.0
# 2             A  Purchase   1422.0
# 3             A  Purchase   1057.0
# 4             C  Purchase   7969.0

# %%
plt.figure(figsize=(6, 4)) # tamaño de figura
sns.boxplot(x="variable", y="value", data=boxplot_blackfriday, palette="Set2", hue='City_Category')

plt.title('Monto segun categoria de ciudad', size=14, pad=15)
plt.legend(loc='best', frameon=False)
plt.xlabel('Ciudad', size=12)
plt.ylabel('Monto', size=12)
sns.despine()
plt.show()

# %% [markdown]
# Paletas Categóricas:
# - deep
# - muted
# - pastel
# - bright
# - dark
# - colorblind
#
# Paletas Secuenciales:
# - rocket
# - mako
# - flare
# - vlag
# - crest
# - cividis
#
# Paletas Divergentes:
# - coolwarm
# - icefire
# - vlag
# - crest
#
# Paletas Misceláneas:
# - husl
# - hls
# - twilight
# - twilight_shifted
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# https://seaborn.pydata.org/tutorial/color_palettes.html
#
# https://seaborn.pydata.org/generated/seaborn.color_palette.html

# %% [markdown]
# #### Scaterplot:
#
#  (o gráfico de dispersión) es una forma simple pero poderosa de visualizar la relación entre dos conjuntos de datos numéricos.
#
# - Puntos en un plano: gráficos con un eje horizontal (x) y un eje vertical (y).
#
# - Relación entre variables: cómo cambia una variable en función de la otra.
#
# Si los puntos se agrupan cerca de una línea diagonal, esto sugiere una relación lineal positiva entre las variables. Si los puntos se alejan de esta línea, sugiere una relación más débil o ninguna relación en absoluto.
#
# - Patrones y tendencias: Los scatterplots son útiles para identificar patrones y tendencias en los datos (tendencia creciente o decreciente en los datos, o si hay agrupamientos o dispersión alrededor de ciertos valores).
#
# - Personalización: color o el tamaño de los puntos, agregando líneas de regresión para mostrar la tendencia general de los datos, o resaltando grupos de puntos utilizando diferentes colores o formas.
#
# Pueden trazar gráficos bidimensionales que se pueden mejorar asignando hasta tres variables adicionales mientras se utiliza la
# semántica de los parámetros de tono, tamaño y estilo.

# %%
# ejemplo
penguins = sns.load_dataset('penguins')

# Crear el scatter plot
plt.figure(figsize=(8, 6))
sns.scatterplot(x='bill_length_mm', y='bill_depth_mm', data=penguins, hue='species')
plt.title('Scatter Plot de Longitud y Profundidad del Pico de los Pingüinos')
plt.xlabel('Longitud del Pico (mm)')
plt.ylabel('Profundidad del Pico (mm)')
plt.legend(title='Especies')
plt.grid(True)

plt.show()

# %% [markdown]
# vemos 3 grupos de especies

# %%
blackfriday.columns
# Out:
# Index(['User_ID', 'Product_ID', 'Gender', 'Age', 'Occupation', 'City_Category',
#        'Stay_In_Current_City_Years', 'Marital_Status', 'Product_Category_1',
#        'Product_Category_2', 'Product_Category_3', 'Purchase'],
#       dtype='object')

# %%
# no todos los gráficos nos dan la mejor información
sns.scatterplot(x="Marital_Status", y="Purchase", data=blackfriday)
# Out:
# <Axes: xlabel='Marital_Status', ylabel='Purchase'>

# %%
sns.scatterplot(x="Marital_Status", y="Purchase", hue="City_Category", data=blackfriday)
# Out:
# <Axes: xlabel='Marital_Status', ylabel='Purchase'>

# %%
'''
g = sns.FacetGrid(blackfriday, col="City_Category", hue="City_Category")
# objeto FacetGrid de Seaborn.
# dividimos los datos en subgráficos basados en los valores únicos de la variable 'City_Category'.
# usamos 'City_Category' como la variable hue, los puntos en cada subgráfico se colorearán según esta variable.

# Mapeamos un scatterplot en cada subgráfico
#  'Marital_Status' en el eje x y 'Purchase' en el eje y
g.map(sns.scatterplot, "Marital_Status", "Purchase")

# Ajustamos el tamaño y espacio entre los subgráficos
g.fig.set_size_inches(12, 6)
g.fig.subplots_adjust(wspace=0.3)

# Agregamos la leyenda por fuera del gráfico
g.add_legend(title="City Category", bbox_to_anchor=(1, 0.5), loc='center left')

# mostramos los gràficos
plt.show()
'''

# %%
plt.figure()
sns.scatterplot(x="Age", y="Purchase",data=blackfriday, palette="spring")
sns.despine()
plt.show()
# Out:
# <ipython-input-72-d25271dde459>:2: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.scatterplot(x="Age", y="Purchase",data=blackfriday, palette="spring")

# %%
'''
# ejemplo subplots
# Datos para los ejes x y y del primer gráfico
x1 = [1, 2, 3, 4, 5]
y1 = [2, 4, 6, 8, 10]

# Datos para los ejes x y y del segundo gráfico
x2 = [1, 2, 3, 4, 5]
y2 = [3, 6, 9, 12, 15]

# Crear la figura y los ejes usando subplots
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(10, 4)) # se puede editar!

# Trazar el primer gráfico en el primer eje
axes[0].plot(x1, y1, color='blue', label='Gráfico 1')
axes[0].set_xlabel('Eje X')
axes[0].set_ylabel('Eje Y')
axes[0].set_title('Primer Gráfico')
axes[0].legend()

# Trazar el segundo gráfico en el segundo eje
axes[1].plot(x2, y2, color='red', label='Gráfico 2')
axes[1].set_xlabel('Eje X')
axes[1].set_ylabel('Eje Y')
axes[1].set_title('Segundo Gráfico')
axes[1].legend()

# Ajustar el diseño de los subgráficos
plt.tight_layout()

# Mostrar la figura con ambos gráficos
plt.show()
'''

# %% [markdown]
# Además de apilar los subgráficos verticalmente, también podemos apilarlos horizontalmente en una misma figura. Para lograr esto, simplemente cambiamos el argumento que pasamos al crear el objeto subplots de Matplotlib

# %%
'''
# Datos para los ejes x y y del primer gráfico
x1 = [1, 2, 3, 4, 5]
y1 = [2, 4, 6, 8, 10]

# Datos para los ejes x y y del segundo gráfico
x2 = [1, 2, 3, 4, 5]
y2 = [3, 6, 9, 12, 15]

# Crear la figura y los ejes usando subplots con orientación horizontal
fig, axes = plt.subplots(nrows=2, ncols=1, figsize=(8, 10)) # aca difrencia!!

# Trazar el primer gráfico en el primer eje
axes[0].plot(x1, y1, color='blue', label='Gráfico 1')
axes[0].set_xlabel('Eje X')
axes[0].set_ylabel('Eje Y')
axes[0].set_title('Primer Gráfico')
axes[0].legend()

# Trazar el segundo gráfico en el segundo eje
axes[1].plot(x2, y2, color='red', label='Gráfico 2')
axes[1].set_xlabel('Eje X')
axes[1].set_ylabel('Eje Y')
axes[1].set_title('Segundo Gráfico')
axes[1].legend()

# Ajustar el diseño de los subgráficos
plt.tight_layout()

# Mostrar la figura con ambos gráficos
plt.show()
'''

# %% [markdown]
# #### Countplot

# %% [markdown]
# Observa como se pueden ajustar la estetica del grafico (Vale para cualquier grafico).

# %%
# conteo de variable
sns.countplot(x="Gender", data=blackfriday)
# "City_Category"
# "Marital_Status"
# "Stay_In_Current_City_Years"
# "Occupation"
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
sns.countplot(x="Occupation", data=blackfriday)
plt.xticks(rotation=45)  # Rotar las etiquetas del eje x en 45 grados
plt.show()

# %%
# plt.figure(figsize=(10, 6))  # Ajustar el tamaño de la figura
sns.countplot(x="Occupation", data=blackfriday)
plt.show()

# %% [markdown]
# ##### Un ejemplo más complejo de countplot

# %%
plt.figure(figsize=(10,5))
sns.countplot(x="Occupation", data=blackfriday.sort_values('Occupation'), palette="Set3")

plt.ylabel("Eventos", size=14)
plt.xlabel("Ocupacion", size=14)
plt.title("Distribucion de la variable ocupacion", size=16, pad=25)
plt.gca().spines["top"].set_visible(False) # ocultar bordes
plt.gca().spines["right"].set_visible(False)
plt.grid(False)
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.countplot(x="Gender", data=blackfriday, palette="Set3")

plt.ylabel("Eventos", size=14)
plt.xlabel("Genero", size=14)
plt.title("Distribucion de la variable genero", size=16, pad=25)
plt.gca().spines["top"].set_visible(False)
plt.gca().spines["right"].set_visible(False)
plt.grid(False)
plt.show()

# %% [markdown]
# #### Graficos solapados
# Vemos 3 graficos

# %%
plt.figure()
sns.displot(blackfriday[blackfriday['City_Category'] == 'A']["Purchase"], color="#a8685e", kde=True)
sns.displot(blackfriday[blackfriday['City_Category'] == 'B']["Purchase"], color="#5ea88e", kde=True)
sns.displot(blackfriday[blackfriday['City_Category'] == 'C']["Purchase"], color="#0f0752", kde=True)
plt.xlabel('Monto de la compra')
plt.ylabel('Frequency')
sns.despine()
plt.show()

# %%
'''
plt.figure(figsize=(12, 6))  # tamaño de la figura

# Subgráfico 1
plt.subplot(1, 3, 1)  # 1 fila, 3 columnas, primer subgráfico
sns.histplot(blackfriday[blackfriday['City_Category'] == 'A']["Purchase"], color="#a8685e", kde=True)
plt.xlabel('Monto de la compra')
plt.ylabel('Frequency')
plt.title('City Category A')
sns.despine()

# Subgráfico 2
plt.subplot(1, 3, 2)  # 1 fila, 3 columnas, segundo subgráfico
sns.histplot(blackfriday[blackfriday['City_Category'] == 'B']["Purchase"], color="#5ea88e", kde=True)
plt.xlabel('Monto de la compra')
plt.ylabel('Frequency')
plt.title('City Category B')
sns.despine()

# Subgráfico 3
plt.subplot(1, 3, 3)  # 1 fila, 3 columnas, tercer subgráfico
sns.histplot(blackfriday[blackfriday['City_Category'] == 'C']["Purchase"], color="#0f0752", kde=True)
plt.xlabel('Monto de la compra')
plt.ylabel('Frequency')
plt.title('City Category C')
sns.despine()

plt.tight_layout()  #  ajustar automáticamente el diseño de los subgráficos para evitar solapamientos
plt.show()
'''

# %% [markdown]
# #### Subplots

# %% [markdown]
# ###### subplots
# Para visualizar dos gráficos (o mas) en una misma figura y compararlos, podemos utilizar la función subplots de Matplotlib. Esta función crea un objeto fig que representa toda la figura (es decir, el lienzo completo donde se realizan los gráficos) y varios ejes en el objeto axes, que corresponden a los distintos subgráficos que vamos a incluir dentro de la figura.
#
# Por ejemplo, si queremos comparar dos gráficos lado a lado, podemos dividir la figura en dos subgráficos utilizando subplots y luego trazar nuestros datos en cada uno de los ejes de forma independiente.

# %%
# Inicio subplots - FILAS - COLUMNAS
fig, ax = plt.subplots(nrows=1, ncols=3, figsize=(10, 4))

# primer grafico
ax[0].hist(blackfriday[blackfriday['City_Category'] == 'A']["Purchase"], color="#a8685e", alpha=0.5, bins=15)
# segundo grafico
ax[1].hist(blackfriday[blackfriday['City_Category'] == 'B']["Purchase"], color="#5ea88e", alpha=0.4, bins=20)
# tercer grafico
ax[2].hist(blackfriday[blackfriday['City_Category'] == 'C']["Purchase"], color="#0f0752", alpha=0.4,  bins=25)
# modifico primer grafico
ax[0].spines["top"].set_visible(False)
ax[0].spines["right"].set_visible(False)
# modifico segundo grafico
ax[1].spines["top"].set_visible(False)
ax[1].spines["right"].set_visible(False)
# modifico tercer grafico
ax[2].spines["top"].set_visible(False)
ax[2].spines["right"].set_visible(False)
plt.show()

# %% [markdown]
# #### Pairplot
#
# gráficos de dispersión. Cada gráfico representa la relación entre dos variables del DataFrame seleccionadas anteriormente.
#
# Un pairplot es una herramienta de visualización que nos permite explorar la **relación** entre todas las variables numéricas en un conjunto de datos. Básicamente, nos muestra un conjunto de gráficos de dispersión, donde cada gráfico muestra la relación entre dos variables. Si tenemos más de dos variables, el pairplot nos muestra todas las combinaciones posibles de gráficos de dispersión entre esas variables
#
# Pairplot también puede utilizar colores para distinguir entre diferentes categorías de una variable categórica. Por ejemplo, si tenemos una variable de género, podemos usar colores diferentes para representar a hombres y mujeres en los gráficos de dispersión

# %%
blackfriday.columns

# %% [markdown]
# hue: Divide los puntos en los gráficos de dispersión en diferentes colores según los valores de la columna 'Gender'

# %%
sns.pairplot(blackfriday[['Stay_In_Current_City_Years', 'Age', 'Purchase', 'Gender']])

# %%
sns.pairplot(blackfriday[['Stay_In_Current_City_Years', 'Age', 'Purchase', 'Gender']], hue='Gender', palette='PuRd');

# %%
corr = blackfriday[['Age', 'Stay_In_Current_City_Years', 'Purchase']].corr(method = 'pearson')

# %% [markdown]
# Este código calcula la **matriz de correlación** entre las variables 'Age', 'Stay_In_Current_City_Years' y 'Purchase' del DataFrame blackfriday.
#
# La matriz de correlación es una tabla que muestra cómo cada par de variables está relacionado entre sí.
#
# En este caso, el método utilizado para calcular la correlación es el coeficiente de **correlación de Pearson**, que mide la fuerza y dirección de la relación lineal entre dos variables continuas
#
# **.corr(method='pearson')**: Calcula la correlación entre estas variables usando el método de correlación de Pearson. Ese método devuelve una matriz cuadrada donde los elementos de la diagonal principal son todos 1 (ya que la correlación de una variable consigo misma es siempre perfecta), y los elementos fuera de la diagonal principal representan la correlación entre pares de variables. Un valor cercano a 1 indica una correlación positiva fuerte, un valor cercano a -1 indica una correlación negativa fuerte, y un valor cercano a 0 indica una correlación débil o nula.
#
#
# ##### ¿como vemos esa correlación?

# %% [markdown]
#  heatmap es una visualización que utiliza colores para representar valores numéricos en una matriz. Funciona mostrando diferentes tonos de color en una cuadrícula, donde cada celda de la cuadrícula representa un par de valores en la matriz.
#
#  annot=True agrega los valores numéricos en cada celda para facilitar la interpretación.

# %%
sns.heatmap(corr, cmap='YlGnBu', annot=True)

# %% [markdown]
# **Otros ejemplos de gráficos**: [Ejemplos en Matplotlib](https://matplotlib.org/3.1.0/gallery/index.html) y [Ejemplos en Seaborn](https://seaborn.pydata.org/examples/index.html)

# %% [markdown]
# ----
# ----
# #### Otros

# %%
#import seaborn as sns
#import matplotlib.pyplot as plt
#import numpy as np

# Cargar el dataset de penguins
penguins = sns.load_dataset('penguins')

# Crear el catplot con intervalo de confianza basado en la desviación estándar y estimador de la mediana
plt.figure(figsize=(8, 6))
sns.catplot(x='species', y='bill_length_mm', data=penguins, ci='sd', estimator=np.median, palette='Set2')
plt.title('Catplot de Longitud del Pico por Especie de Pingüino')
plt.xlabel('Especie')
plt.ylabel('Longitud del Pico (mm)')
plt.grid(True)
plt.show()

# %%
#import seaborn as sns
#import matplotlib.pyplot as plt

# Cargar el dataset de penguins
penguins = sns.load_dataset('penguins')

# Crear el jointplot
sns.jointplot(x='bill_length_mm', y='bill_depth_mm', data=penguins, kind='scatter')
plt.suptitle('Jointplot de Longitud vs Profundidad del Pico de los Pingüinos', y=1.02)
plt.show()

# %%
# Cargar el dataset de penguins
#penguins = sns.load_dataset('penguins')

# Contar el número de registros por especie
species_counts = penguins['species'].value_counts()

# Crear el gráfico de torta
plt.figure(figsize=(8, 6))
plt.pie(species_counts, labels=species_counts.index, autopct='%1.1f%%', colors=['#1f77b4', '#ff7f0e', '#2ca02c'])
plt.title('Distribución de Especies de Pingüinos')
plt.axis('equal')  # Para que el gráfico de torta se muestre como un círculo
plt.show()

# %% [markdown]
# **Seaborn:**
#
# - Seaborn es ideal para la visualización de datos estadísticos y complejos.
# - Funciona bien con DataFrames de Pandas y se integra perfectamente con las funcionalidades de Pandas.
# - Es especialmente útil para crear gráficos estadísticos, como diagramas de dispersión con regresión, diagramas de caja, gráficos de violín y gráficos de distribución conjunta.
# - Seaborn proporciona una interfaz de alto nivel para crear gráficos con estilos atractivos y colores predefinidos.
#
# **Matplotlib:**
#
# - Matplotlib es una biblioteca de bajo nivel que proporciona un control completo sobre los detalles de la visualización.
# - Es útil cuando se necesita una personalización completa o cuando se quieren crear gráficos que no están disponibles en Seaborn.
# - Ofrece una amplia gama de funciones para crear gráficos 2D y 3D, incluyendo gráficos de dispersión simples, gráficos de líneas, gráficos de barras, gráficos de torta, etc.
# - Matplotlib es especialmente útil cuando se necesita un control preciso sobre aspectos como el tamaño de la figura, la disposición de los ejes y las etiquetas, y la personalización de los estilos de línea y color.
#
# **Combinación:**
# - Seaborn y Matplotlib pueden combinarse fácilmente en un mismo script.
# - Seaborn utiliza Matplotlib por debajo, por lo que es posible personalizar aún más los gráficos creados por Seaborn utilizando las funciones de Matplotlib.
#
# Por ejemplo, se pueden agregar títulos, etiquetas de ejes adicionales, anotaciones y personalización de colores a los gráficos de Seaborn utilizando las funciones de Matplotlib.

# %% [markdown]
# - Gráfico de barras para variables categóricas:
#
# **sns.countplot:** para visualizar la distribución de las variables categóricas como "Gender", "City_Category", "Marital_Status", etc.
#
# - Gráfico de distribución para variables numéricas:
#
# **sns.histplot o sns.distplot:**  distribución de variables numéricas como "Age", "Occupation", "Stay_In_Current_City_Years", etc.
#
# - Gráfico de dispersión para relaciones entre variables numéricas:
#
# **sns.scatterplot:** relaciones entre dos variables numéricas, como "Age" vs "Purchase", "Occupation" vs "Purchase", etc.
#
# - Gráfico de caja para comparar distribuciones:
#
# **sns.boxplot:** distribución de una variable numérica entre diferentes categorías, por ejemplo, "Purchase" en diferentes "City_Category".
#
# - Mapas de calor para correlación:
#
# **sns.heatmap:** entre todas las variables numéricas en tu conjunto de datos

# %% [markdown]
# - ax.set_xlabel(titulo) : Añade un título con el contenido de la cadena titulo al eje x de ax. Se puede personalizar la alineación y la fuente con los mismos parámetros que para el título principal.
# - ax.set_ylabel(titulo) : Añade un título con el contenido de la cadena titulo al eje y de ax. Se puede personalizar la alineación y la fuente con los mismos parámetros que para el título principal.
# - ax.set_xlim([limite-inferior, limite-superior]) : Establece los límites que se muestran en el eje x de ax.
# - ax.set_ylim([limite-inferior, limite-superior]) : Establece los límites que se muestran en el eje y de ax.
# - ax.set_xticks(marcas) : Dibuja marcas en el eje x de ax en las posiciones indicadas en la lista marcas.
# - ax.set_yticks(marcas) : Dibuja marcas en el eje y de ax en las posiciones indicadas en la lista marcas.
# - ax.set_xscale(escala) : Establece la escala del eje x de ax, donde el parámetro escala puede ser 'linear' (lineal) o 'log' (logarítmica).
# - ax.set_yscale(escala) : Establece la escala del eje y de ax, donde el parámetro escala puede ser 'linear' (lineal) o 'log' (logarítmica).

# %% [markdown]
# ## Para seguir jugando (no incluidos en clase)
# Destinado a alumnas que buscan otros gráficos

# %%
import numpy as np
import matplotlib.pyplot as plt

def f(x, y):
    return (1 - x / 2 + x ** 5 + y ** 3 ) * np.exp(-x ** 2 - y ** 2)

# Definir el número de puntos a lo largo de cada eje
n = 10

# Crear arreglos de puntos a lo largo de los ejes x e y
x = np.linspace(-3, 3, int(3.5 * n))  # Crear 35 puntos a lo largo del eje x
y = np.linspace(-3, 3, int(3.0 * n))  # Crear 30 puntos a lo largo del eje y

# Crear una cuadrícula de coordenadas X e Y utilizando meshgrid
X, Y = np.meshgrid(x, y)

# Calcular los valores Z (altura) para cada par de coordenadas (X, Y)
Z = f(X, Y)

# Crear una figura y ejes en las posiciones y tamaños especificados
plt.axes([0.025, 0.025, 0.95, 0.95])

# Mostrar la matriz Z como una imagen
# interpolation='nearest' especifica que los píxeles de la imagen se muestran sin interpolación
# cmap='bone' especifica la paleta de colores que se utilizará para la imagen
# origin='lower' especifica que el origen de la imagen se encuentra en la esquina inferior izquierda
plt.imshow(Z, interpolation='nearest', cmap='bone', origin='lower')

# Agregar una barra de color asociada a los valores de Z en la imagen
# shrink=.92 especifica el factor de escala para la barra de color
plt.colorbar(shrink=.92)

# Eliminar los ticks del eje x e y
plt.xticks(())
plt.yticks(())

# Mostrar la visualización
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
# Crear una nueva figura
fig = plt.figure()

# Añadir un subplot 3D a la figura
ax = fig.add_subplot(111, projection='3d')

# Definir los valores de X e Y en el rango de -4 a 4 con un paso de 0.25
X = np.arange(-4, 4, 0.25)
Y = np.arange(-4, 4, 0.25)

# Crear una malla de coordenadas X e Y
X, Y = np.meshgrid(X, Y)

# Calcular el radio R a partir de las coordenadas X e Y
R = np.sqrt(X ** 2 + Y ** 2)

# Calcular los valores de Z a partir de la función sin(R)
Z = np.sin(R)

# Crear una superficie 3D a partir de los datos de X, Y y Z
ax.plot_surface(X, Y, Z, rstride=1, cstride=1, cmap=plt.cm.hot)

# Añadir un gráfico de contorno en el plano Z = -2
ax.contourf(X, Y, Z, zdir='z', offset=-2, cmap=plt.cm.hot)

# Limitar el rango del eje z de -2 a 2
ax.set_zlim(-2, 2)

# Mostrar la figura
plt.show()

# %% [markdown]
# https://matplotlib.org/2.0.2/users/pyplot_tutorial.html
#
# https://matplotlib.org/2.0.2/users/image_tutorial.html
#
# https://matplotlib.org/2.0.2/users/transforms_tutorial.html
